# %%
#Importando las librerias necesarias para el analisis de GEIH
import pandas as pd
import numpy as np

# %%
#Leyendo los datos de la geihs
df_cgsse = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV"
                       ,encoding="latin", sep=';')
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
df_d = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV"
                             ,encoding="latin", sep=';')
df_d
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238975            1      2      1     70
# 1      20250626    6  2025     8238978            1      1      1     70
# 2      20250626    6  2025     8238980            1      2      1     70
# 3      20250626    6  2025     8238981            1      2      1     70
# 4      20250626    6  2025     8238983            1      2      1     70
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 24739  20250626    6  2025     8283056            1      1      1     70
# 24740  20250626    6  2025     8283059            1      1      1     70
# 24741  20250626    6  2025     8283060            1      1      1     70
# 24742  20250626    6  2025     8283062            1      2      1     70
# 24743  20250626    6  2025     8283062            1      3      1     70
#
#        AREA  CLASE  ...  P7360  P9460  P1519  P1883  P7422  P7422S1  \
# ...

# %%
df_o = pd.read_csv ("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV"
                           ,encoding="latin", sep=';')
df_o
# Out:
# /tmp/ipykernel_2931/1250740375.py:1: DtypeWarning: Columns (28,89,133,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_o = pd.read_csv ("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV"
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     60
# 1      20250626    6  2025     8238974            1      2      1     60
# 2      20250626    6  2025     8238975            1      1      1     60
# 3      20250626    6  2025     8238975            1      3      1     60
# 4      20250626    6  2025     8238976            1      1      1     60
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 29701  20250626    6  2025     8283057            1      3      1     60
# 29702  20250625    6  2025     8283058            1      1      1     60
# ...

# %%
df_ft = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV"
                                ,encoding="latin", sep=';')
df_ft
# Out:
# /tmp/ipykernel_2931/979928258.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ft = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV"
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     50
# 1      20250626    6  2025     8238974            1      2      1     50
# 2      20250626    6  2025     8238975            1      1      1     50
# 3      20250626    6  2025     8238975            1      2      1     50
# 4      20250626    6  2025     8238975            1      3      1     50
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 54445  20250626    6  2025     8283060            1      1      1     50
# 54446  20250626    6  2025     8283060            1      2      1     50
# ...

# %%
df_cgsse[['DIRECTORIO','SECUENCIA_P','ORDEN', 'FEX_C18']]
# Out:
#        DIRECTORIO  SECUENCIA_P  ORDEN    FEX_C18
# 0         8238974            1      1  67.484133
# 1         8238974            1      2  67.484133
# 2         8238975            1      1  54.337978
# 3         8238975            1      2  54.337978
# 4         8238975            1      3  54.337978
# ...           ...          ...    ...        ...
# 67851     8283060            1      1  47.033269
# 67852     8283060            1      2  47.033269
# 67853     8283062            1      1  32.850300
# 67854     8283062            1      2  32.850300
# 67855     8283062            1      3  32.850300
#
# [67856 rows x 4 columns]

# %%
#DIRECTORIO: Identifica la vivienda
#SECUENCIA_P : Identifica el hogar
#ORDEN: Personas en la vivienda

# %%
df_cgsse['DIRECTORIO'].unique().tolist()
# Out:
# [8238974,
#  8238975,
#  8238976,
#  8238977,
#  8238978,
#  8238979,
#  8238980,
#  8238981,
#  8238982,
#  8238983,
#  8238984,
#  8238985,
#  8238986,
#  8238987,
#  8238988,
#  8238989,
#  8238990,
#  8238991,
#  8238992,
#  8238993,
#  8238994,
#  8238995,
#  8238996,
#  8238997,
#  8238998,
#  8238999,
#  8239000,
#  8239001,
#  8239002,
#  8239003,
#  8239004,
#  8239005,
#  8239006,
#  8239007,
#  8239008,
#  8239009,
#  8239010,
#  8239011,
#  8239012,
#  8239013,
#  8239014,
#  8239015,
#  8239016,
#  8239017,
#  8239018,
#  8239019,
#  8239020,
#  8239021,
#  8239022,
#  8239023,
#  8239024,
#  8239025,
#  8239026,
#  8239027,
#  8239028,
#  8239029,
#  8239030,
#  8239031,
#  8239032,
#  8239033,
#  8239034,
#  8239035,
#  8239036,
#  8239037,
#  8239038,
#  8239039,
#  8239040,
#  8239041,
#  8239042,
#  8239043,
#  8239044,
#  8239045,
#  8239046,
#  8239047,
#  8239048,
#  8239049,
#  8239050,
#  8239051,
#  8239052,
#  8239053,
#  8239054,
#  8239055,
#  8239056,
# ...

# %%
#CON ESTE CODIGO PODEMOS VER INFO DE UN DIRECTORIO EN ESPECIFICO PARA SACAR CONCLUSIONES
df_cgsse[df_cgsse['DIRECTORIO']==8238998]
# Out:
#      PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 62  20250626    6  2025     8238998            1      1      1     10   NaN
# 63  20250626    6  2025     8238998            1      2      1     10   NaN
# 64  20250626    6  2025     8238998            1      3      1     10   NaN
# 65  20250626    6  2025     8238998            1      4      1     10   NaN
#
#     CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  P3043S1  P3038  \
# 62      1  ...    2.0    NaN    5.0      2.0      NaN    2.0      NaN    2.0
# 63      1  ...    2.0    NaN    5.0      2.0      NaN    2.0      NaN    1.0
# 64      1  ...    2.0    NaN    5.0      2.0      NaN    2.0      NaN    1.0
# 65      1  ...    2.0    NaN    5.0      2.0      NaN    2.0      NaN    1.0
#
#     P3039  POB_MAY18
# 62    1.0        1.0
# 63    2.0        1.0
# 64    2.0        1.0
# 65    1.0        1.0
#
# [4 rows x 55 columns]

# %%
#CALCULAR POBLACION TOTAL
int(df_cgsse['FEX_C18'].sum())
# Out:
# 52045001

# %%
int(df_cgsse['FEX_C18'].sum())

#Calculo de la poblacion total de hombres
PH= df_cgsse[df_cgsse['P3271']==1]['FEX_C18'].sum()

#Calculo de la poblacion total de mujere
PM=df_cgsse[df_cgsse['P3271']==2]['FEX_C18'].sum()

print(f'Poblacion total de hombres: {PH}')
print(f'Poblacion total de mujeres: {PM}')
# Out:
# Poblacion total de hombres: 25304270.000003804
# Poblacion total de mujeres: 26740731.000005245

# %% [markdown]
# DEPARTAMENTO DEL QUINDÍO

# %%
PQ = df_cgsse[df_cgsse["DPTO"]==63]["FEX_C18"].sum()
print(f" POBLACION QUINDIO: {PQ}")
# Out:
#  POBLACION QUINDIO: 603068.649439007

# %%
PHQ = df_cgsse[(df_cgsse["DPTO"]==63) & (df_cgsse["P3271"]==1)]["FEX_C18"].sum()
PMQ = df_cgsse[(df_cgsse["DPTO"]==63) & (df_cgsse["P3271"]==2)]["FEX_C18"].sum()
print("HOMBRES QUINDÍO", int (PHQ))
print("MUJERES QUINDÍO", int (PMQ))
# Out:
# HOMBRES QUINDÍO 297925
# MUJERES QUINDÍO 305143

# %% [markdown]
# 25/08/2025

# %%
#POBLACION OCUPADOS
int(df_o['FEX_C18'].sum())
# Out:
# 23752952

# %%
#POBLACION FUERZA DE TRABAJO
int(df_ft['FEX_C18'].sum())
# Out:
# 40653416

# %%
#POBLACION DESOCUPADOS
int(df_d['FEX_C18'].sum())
# Out:
# 16900463

# %%
#POBLACION TOTAL O DE FUERZA DE TRABAJO 
16900463+23752952
# Out:
# 40653415

# %%
#CALCULO DE HOMBRES EN DESEMPLEO
df_d_genero =
# Out:
#   Cell In[50], line 2
#     df_d_genero =
#                   ^
# SyntaxError: invalid syntax

# %%
df_o_genero = pd.merge(df_o, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

# %%
#Calculo de hombres ocupados 
dh = df_o_genero[df_o_genero['P3271'] == 1]['FEX_C18'].sum()

#Calculo de mujeres ocupadas 

dm = df_o_genero[df_o_genero['P3271'] == 2]['FEX_C18'].sum()

print (f'Hombres en empleo: {int(dh)}')
print (f'Mujeres en empleo: {int(dm)}')
# Out:
# Hombres en empleo: 13860862
# Mujeres en empleo: 9892089

# %%
df_d_genero = pd.merge(df_d, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

# %%
#Calculo de hombres ocupados 
dh = df_d_genero[df_d_genero['P3271'] == 1]['FEX_C18'].sum()

#Calculo de mujeres ocupadas 

dm = df_d_genero[df_d_genero['P3271'] == 2]['FEX_C18'].sum()

print (f'Hombres en desempleo: {int(dh)}')
print (f'Mujeres en desempleo: {int(dm)}')
# Out:
# Hombres en desempleo: 5637651
# Mujeres en desempleo: 11262812

# %%
df_d.columns
# Out:
# Index(['PERIODO', 'MES', 'PER', 'DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'HOGAR',
#        'REGIS', 'AREA', 'CLASE', 'FEX_C18', 'DPTO', 'FFT', 'DSI', 'P7250',
#        'P7280', 'P7280S1', 'P744', 'P3074', 'P7260', 'P1806', 'P7430', 'P7440',
#        'P7440S1', 'P7440S2', 'P7450', 'P7350', 'P7360', 'P9460', 'P1519',
#        'P1883', 'P7422', 'P7422S1', 'OFICIO1_C8', 'OFICIO2_C8', 'RAMA2D_D_R4',
#        'RAMA4D_D_R4'],
#       dtype='object')

# %% [markdown]
# EJERCICIO DE LA COMMIT

# %%
df_cgsse = pd.read_csv("https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/refs/heads/main/Datos/GEIH2025/cgsse.CSV",encoding = "latin", sep=";")

# %%
df_cgsse = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV'
                       ,encoding='latin',sep=';'
                       )

df_o = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
                       ,encoding='latin',sep=';'
                       )

df_d = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV'
                       ,encoding='latin',sep=';'
                       )

df_ft = pd.read_csv('https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'
                       ,encoding='latin',sep=';'

# %%
url_cgsse = ('https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/cgsse.CSV')
url_ocupados = 'https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/Ocupados.CSV'
url_ft = 'https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'
url_desocupados = 'https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/No%20ocupados.CSV'

# %%
#CGSSE
df_cgsse = pd.read_csv(url_cgsse, encoding='latin-1', sep=';', low_memory=False)
#ocupados
df_ocupados=pd.read_csv(url_ocupados,encoding='latin-1',sep=';',
                        low_memory=False)
#fuerza de trabajo
df_ft=pd.read_csv(url_ft,
                  encoding='latin-1',sep=';',low_memory=False)
#no ocupados
df_desocupados=pd.read_csv(url_desocupados,encoding='latin-1',
                           sep=';',low_memory=False)

# %%
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
df_cgsse['FEX_C18'].sum()
# Out:
# np.float64(52045001.000009045)

# %%
df_ocupados
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     60
# 1      20250626    6  2025     8238974            1      2      1     60
# 2      20250626    6  2025     8238975            1      1      1     60
# 3      20250626    6  2025     8238975            1      3      1     60
# 4      20250626    6  2025     8238976            1      1      1     60
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 29701  20250626    6  2025     8283057            1      3      1     60
# 29702  20250625    6  2025     8283058            1      1      1     60
# 29703  20250625    6  2025     8283058            1      2      1     60
# 29704  20250626    6  2025     8283060            1      2      1     60
# 29705  20250626    6  2025     8283062            1      1      1     60
#
#        AREA  CLASE  ...  P1881  P1881S1  P1882  P7240  P7240S1  OCI  \
# ...

# %%
df_ft
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     50
# 1      20250626    6  2025     8238974            1      2      1     50
# 2      20250626    6  2025     8238975            1      1      1     50
# 3      20250626    6  2025     8238975            1      2      1     50
# 4      20250626    6  2025     8238975            1      3      1     50
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 54445  20250626    6  2025     8283060            1      1      1     50
# 54446  20250626    6  2025     8283060            1      2      1     50
# 54447  20250626    6  2025     8283062            1      1      1     50
# 54448  20250626    6  2025     8283062            1      2      1     50
# 54449  20250626    6  2025     8283062            1      3      1     50
#
#        AREA  CLASE  ...  P3362S8  P3362S7A1  P6300  P6310  P6310S1  P6320  \
# ...

# %%
df_desocupados
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238975            1      2      1     70
# 1      20250626    6  2025     8238978            1      1      1     70
# 2      20250626    6  2025     8238980            1      2      1     70
# 3      20250626    6  2025     8238981            1      2      1     70
# 4      20250626    6  2025     8238983            1      2      1     70
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 24739  20250626    6  2025     8283056            1      1      1     70
# 24740  20250626    6  2025     8283059            1      1      1     70
# 24741  20250626    6  2025     8283060            1      1      1     70
# 24742  20250626    6  2025     8283062            1      2      1     70
# 24743  20250626    6  2025     8283062            1      3      1     70
#
#        AREA  CLASE  ...  P7360  P9460  P1519  P1883  P7422  P7422S1  \
# ...

# %%
#nueva celda para el ejemplo del commit
df_o.head()
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250626    6  2025     8238974            1      1      1     60   NaN
# 1  20250626    6  2025     8238974            1      2      1     60   NaN
# 2  20250626    6  2025     8238975            1      1      1     60   NaN
# 3  20250626    6  2025     8238975            1      3      1     60   NaN
# 4  20250626    6  2025     8238976            1      1      1     60   NaN
#
#    CLASE  ...  P1881  P1881S1  P1882  P7240  P7240S1  OCI    INGLABO  \
# 0      2  ...      3      NaN    3.0      3      NaN    1   950000.0
# 1      2  ...      3      NaN    4.0      5      NaN    1        NaN
# 2      2  ...      3      NaN   10.0      3      NaN    1   700000.0
# 3      2  ...      3      NaN   10.0      3      NaN    1  2000000.0
# 4      2  ...     14      NaN    NaN      8      NaN    1   600000.0
#
#    RAMA2D_R4  RAMA4D_R4  OFICIO_C8
# 0          1        113       6111
# ...

# %%
df_cgsse2 =  pd.read_csv("https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/refs/heads/main/Datos/GEIH2025/cgsse.CSV",encoding = "latin", sep=";")
df_cgsse2
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
url_cgsse2025 = ('https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/cgsse.CSV')
url_ocupados2025 = ('https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/Ocupados.CSV')
url_ft2025= ('https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV')
url_desocupados2025 = ('https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/main/Datos/GEIH2025/No%20ocupados.CSV')

# %%
df_cgsse2 = pd.read_csv(url_cgsse, encoding='latin-1', sep=';', low_memory=False)
df_cgsse2
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
df_cgsse2[["DIRECTORIO","SECUENCIA_P","ORDEN"]]
# Out:
#        DIRECTORIO  SECUENCIA_P  ORDEN
# 0         8238974            1      1
# 1         8238974            1      2
# 2         8238975            1      1
# 3         8238975            1      2
# 4         8238975            1      3
# ...           ...          ...    ...
# 67851     8283060            1      1
# 67852     8283060            1      2
# 67853     8283062            1      1
# 67854     8283062            1      2
# 67855     8283062            1      3
#
# [67856 rows x 3 columns]

# %%
df_cgsse2["DIRECTORIO"].unique().tolist()
# Out:
# [8238974,
#  8238975,
#  8238976,
#  8238977,
#  8238978,
#  8238979,
#  8238980,
#  8238981,
#  8238982,
#  8238983,
#  8238984,
#  8238985,
#  8238986,
#  8238987,
#  8238988,
#  8238989,
#  8238990,
#  8238991,
#  8238992,
#  8238993,
#  8238994,
#  8238995,
#  8238996,
#  8238997,
#  8238998,
#  8238999,
#  8239000,
#  8239001,
#  8239002,
#  8239003,
#  8239004,
#  8239005,
#  8239006,
#  8239007,
#  8239008,
#  8239009,
#  8239010,
#  8239011,
#  8239012,
#  8239013,
#  8239014,
#  8239015,
#  8239016,
#  8239017,
#  8239018,
#  8239019,
#  8239020,
#  8239021,
#  8239022,
#  8239023,
#  8239024,
#  8239025,
#  8239026,
#  8239027,
#  8239028,
#  8239029,
#  8239030,
#  8239031,
#  8239032,
#  8239033,
#  8239034,
#  8239035,
#  8239036,
#  8239037,
#  8239038,
#  8239039,
#  8239040,
#  8239041,
#  8239042,
#  8239043,
#  8239044,
#  8239045,
#  8239046,
#  8239047,
#  8239048,
#  8239049,
#  8239050,
#  8239051,
#  8239052,
#  8239053,
#  8239054,
#  8239055,
#  8239056,
# ...

# %%
df_cgsse2[df_cgsse2["DIRECTORIO"]==8238991]
# Out:
#      PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 40  20250626    6  2025     8238991            1      1      1     10   NaN
# 41  20250626    6  2025     8238991            1      2      1     10   NaN
#
#     CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  P3043S1  P3038  \
# 40      1  ...    2.0    NaN    1.0      0.0      NaN    NaN      NaN    2.0
# 41      1  ...    2.0    NaN    1.0      0.0      NaN    NaN      NaN    1.0
#
#     P3039  POB_MAY18
# 40    1.0        1.0
# 41    2.0        1.0
#
# [2 rows x 55 columns]

# %%
df_cgsse2[["DIRECTORIO","SECUENCIA_P","ORDEN","PER"]]
# Out:
#        DIRECTORIO  SECUENCIA_P  ORDEN   PER
# 0         8238974            1      1  2025
# 1         8238974            1      2  2025
# 2         8238975            1      1  2025
# 3         8238975            1      2  2025
# 4         8238975            1      3  2025
# ...           ...          ...    ...   ...
# 67851     8283060            1      1  2025
# 67852     8283060            1      2  2025
# 67853     8283062            1      1  2025
# 67854     8283062            1      2  2025
# 67855     8283062            1      3  2025
#
# [67856 rows x 4 columns]

# %%
#CALCULAR POBLACIÓN TOTAL
PT =  df_cgsse2['FEX_C18'].sum()
print(f' La población total de referencia para Colombia basado en el modulo cgsse de la GEIH y el factor de expansión es {PT}')
# Out:
#  La población total de referencia para Colombia basado en el modulo cgsse de la GEIH y el factor de expansión es 52045001.000009045

# %%
int(df_o['FEX_C18'].sum())
# Out:
# 23752952

# %%
int(df_d['FEX_C18'].sum())
# Out:
# 16900463

# %%
#población total: desagregación hombres y mujeres
PH = df_cgsse2[df_cgsse2['P3271']==1]['FEX_C18'].sum()
PM = df_cgsse2[df_cgsse2['P3271']==2]['FEX_C18'].sum()
print(f' Hombres : {PH}')
print(f' Mujeres:  {PM}')
# Out:
#  Hombres : 25304270.000003804
#  Mujeres:  26740731.000005245

# %%
# calcular población total del quindío
PTQ = df_cgsse2[df_cgsse2["DPTO"]==63]["FEX_C18"].sum()
PTQ
# Out:
# np.float64(603068.649439007)

# %%
#Calculando cantidad de hombres y de mujeres
PHQ = df_cgsse[(df_cgsse['DPTO']==63) & (df_cgsse['P3271']==1)]['FEX_C18'].sum()
PMQ = df_cgsse[(df_cgsse['DPTO']==63) & (df_cgsse['P3271']==2)]['FEX_C18'].sum()
print(f' Hombres del Quindio : {PHQ}')
print(f' Mujeres del Quindio:  {PMQ}')
# Out:
#  Hombres del Quindio : 297925.64044618
#  Mujeres del Quindio:  305143.00899282703

# %%
16900463+23752952
# Out:
# 40653415

# %%
#Calculo de hombres en desempleo 
df_d_genero = pd.merge(df_o, df_cgsse[["DIRECTORIO","SECUENCIA_P","ORDEN","P3271"]],on=["DIRECTORIO","SECUENCIA_P","ORDEN"],how = "left")

# %%
#calculo de hombres en desempleo
dh = df_d_genero[df_d_genero["P3271"]==1]["FEX_C18"].sum()

# %%
#calculo mujeres en desempleo
dm = df_d_genero[df_d_genero["P3271"]==2]["FEX_C18"].sum()

# %%
print (f"Hombres en desempleo: {int(dh)}")
# Out:
# Hombres en desempleo: 13860862

# %%
print (f"Mujeres en desempleo: {int(dm)}")
# Out:
# Mujeres en desempleo: 9892089

# %%
#agregar columnas de características generales hacia no ocupados
df_n_o_genero = pd.merge(df_d,df_cgsse2[["DIRECTORIO","SECUENCIA_P","ORDEN","P3271"]],on = ["DIRECTORIO","SECUENCIA_P","ORDEN"], how = "left")

# %%
#mujeres en empleo
Phno = df_n_o_genero[df_n_o_genero["P3271"]==1]["FEX_C18"].sum()
Phmo = df_n_o_genero[df_n_o_genero["P3271"]==2]["FEX_C18"].sum()

# %%
print(f"Hombres : {Phno}")
print(f"Mujeres : {Phmo}")
# Out:
# Hombres : 5637651.124199245
# Mujeres : 11262812.215548996

# %%
#Agregar columnas de características generales hacia Fuerza de trabajo
df_f_genero = pd.merge(df_ft,df_cgsse2[["DIRECTORIO","SECUENCIA_P","ORDEN","P3271"]], on = ["DIRECTORIO","SECUENCIA_P","ORDEN"], how = "left")

# %%
Phf = df_f_genero[df_f_genero["P3271"]==1]["FEX_C18"].sum()
Pmf = df_f_genero[df_f_genero["P3271"]==2]["FEX_C18"].sum()

# %%
#resultados
print(f"Hombres : {Phf}")
print(f"Mujeres : {Pmf}")
# Out:
# Hombres : 19498514.00000009
# Mujeres : 21154902.000004

# %%
#sacar la población total de desempleo en el quindío, sacar cantidad de hombres y mujeres desempleados en el Quindío.
PhQ =  df_n_o_genero[(df_n_o_genero["DPTO"]==63)&(df_n_o_genero["P3271"]==1)]["FEX_C18"].sum()
Phm = df_n_o_genero[(df_n_o_genero["DPTO"]==63)&(df_n_o_genero["P3271"]==2)]["FEX_C18"].sum()
print (f"Hombres en desempleo en el Quindío : {PhQ}")
print (f"Mujeres en desempleo en el Quindío : {Phm}")
# Out:
# Hombres en desempleo en el Quindío : 90281.15984383199
# Mujeres en desempleo en el Quindío : 155120.58323295298
