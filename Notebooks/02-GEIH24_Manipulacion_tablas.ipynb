# %%
#Importando las librerias necesarias para el analisis de GEIH
import pandas as pd
import numpy as np

# %%
#Leyendo los datos de la geihs
df_cgsse = pd.read_csv("https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/refs/heads/main/Datos/GEIH2024/CGSSE.CSV"
                       ,encoding="latin", sep=';')
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20240730    7  2024     7858603            1      1      1     10
# 1      20240730    7  2024     7858603            1      2      1     10
# 2      20240730    7  2024     7858603            1      3      1     10
# 3      20240730    7  2024     7858604            1      1      1     10
# 4      20240730    7  2024     7858604            1      2      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 69689  20240730    7  2024     7889227            1      1      1     10
# 69690  20240730    7  2024     7889227            1      2      1     10
# 69691  20240730    7  2024     7889227            1      3      1     10
# 69692  20240730    7  2024     7889227            1      4      1     10
# 69693  20240730    7  2024     7889227            1      5      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# ...

# %%
df_no_ocupados = pd.read_csv("https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/refs/heads/main/Datos/GEIH2024/No%20ocupados.CSV"
                             ,encoding="latin", sep=';')
df_no_ocupados
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20240730    7  2024     7858603            1      2      1     70
# 1      20240730    7  2024     7858605            1      2      1     70
# 2      20240730    7  2024     7858606            1      3      1     70
# 3      20240730    7  2024     7858607            1      2      1     70
# 4      20240730    7  2024     7858607            1      3      1     70
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 25104  20240727    7  2024     7889223            1      4      1     70
# 25105  20240728    7  2024     7889224            1      2      1     70
# 25106  20240728    7  2024     7889224            1      3      1     70
# 25107  20240729    7  2024     7889226            1      2      1     70
# 25108  20240730    7  2024     7889227            1      2      1     70
#
#        AREA  CLASE  ...  P9460  P1519  P1883  P7422   P7422S1  OFICIO1_C8  \
# ...

# %%
df_ocupados = pd.read_csv ("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2024/Ocupados.CSV"
                           , encoding="latin", sep=';')
df_ocupados
# Out:
# /tmp/ipykernel_20157/1502321250.py:1: DtypeWarning: Columns (28,89,135,150,161) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ocupados = pd.read_csv ("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2024/Ocupados.CSV"
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20240730    7  2024     7858603            1      1      1     60
# 1      20240730    7  2024     7858603            1      3      1     60
# 2      20240730    7  2024     7858604            1      1      1     60
# 3      20240730    7  2024     7858604            1      2      1     60
# 4      20240730    7  2024     7858605            1      1      1     60
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 29924  20240728    7  2024     7889224            1      1      1     60
# 29925  20240729    7  2024     7889226            1      1      1     60
# ...

# %%
df_fuerza_trabajo = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2024/Fuerza%20de%20trabajo.CSV"
                                ,encoding="latin", sep=';')
df_fuerza_trabajo
# Out:
# /tmp/ipykernel_20157/4004692546.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fuerza_trabajo = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2024/Fuerza%20de%20trabajo.CSV"
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20240730    7  2024     7858603            1      1      1     50
# 1      20240730    7  2024     7858603            1      2      1     50
# 2      20240730    7  2024     7858603            1      3      1     50
# 3      20240730    7  2024     7858604            1      1      1     50
# 4      20240730    7  2024     7858604            1      2      1     50
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 55033  20240729    7  2024     7889226            1      2      1     50
# 55034  20240730    7  2024     7889227            1      1      1     50
# ...
